# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import cross_val_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score

##Seaborn for fancy plots. 
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams["figure.figsize"] = (8,8)
from ml_eda import edaDF2

# %% [markdown]
# ## 3950 Assignment 1: Part 2
#
# For this assignment we want to use some sort of tree based model to classify the data below. We have a very small training set, so overfitting is a very real concern.
#
# Some specifics for this assignment:
# <ul>
# <li>Please use the show_eda to control if EDA stuff is shown. I don't really need to see all the EDA stuff (nor do you after you've done it), so we can make it configurable with a variable to speed up time. Please set this FALSE when you submit, so I can run all and see the outcome without histograms etc...
# <li>Please ensure that whatever model you end up with is in a variable named best at the end.
# <li>Please use some pipeline in prepping the data. The test data is in an identical format to the training data, so whatever pipeline you've created for your training will work for the testing.
# <li>The accuracy scoring will be an average of accuracy and roc_auc.
# </ul>
#
# ### Grading Metrics
# <ul>
# <li><b>Pipeline Used - 10pts</b> The data loading needs to be in a pipeline. See the test part for illustration. When testing I'll call your pipe with the new data (format is identical to training), so any prep stuff should be in the pipeline.
# <li><b>Tree Based Model Used - 5pts</b> The model used for classification needs to be some variety of tree, beyond that it is up to you.
# <li><b>Accuracy - 5pts</b> The final accuracy acheived. This will be a rough ranking, I'm assuming most people will get a similar level of accuracy, marks will only be deducted if yours is far wosrse, as that's an indication that you probably didn't take any/many steps to improve things.
# <li><b>Clarity and Formatting - 5pts</b> Is it organized and can I read it?
#     <ul>
#     <li> <b>Note:</b> for this assignment, and in general, please get rid of my comments and replace them with your own. I'm going to read this, so all of these instructions aren't really required. Think of this as a template, get rid of the stuff that isn't needed, and leave only the things you need to explain your code.
#     </ul>
# </ul>
#
# For submission, please drop the URL for your repository in the dropbox.

# %%
#Please change to your name.
name = "Nneka Okoh"

#Please use this to control EDA. 
show_eda = False

# %%
#Load data
df = pd.read_csv("training.csv")
df = df.drop(columns={"id"})
df.sample(5)
# Out:
#      target  var_1  var_2  var_3  var_4  var_5  var_6  var_7  var_8  var_9  \
# 45        1  0.527  0.432  0.164  0.568  0.747  0.474  0.187  0.303  0.381
# 158       1  0.792  0.500  0.876  0.187  0.120  0.161  0.206  0.510  0.466
# 14        1  0.975  0.099  0.632  0.257  0.903  0.837  0.107  0.019  0.307
# 219       1  0.132  0.542  0.059  0.205  0.867  0.024  0.810  0.616  0.893
# 208       0  0.223  0.924  0.457  0.888  0.692  0.428  0.459  0.585  0.742
#
#      ...  var_191  var_192  var_193  var_194  var_195  var_196  var_197  \
# 45   ...    0.566    0.369    0.069    0.086    0.370    0.446    0.623
# 158  ...    0.537    0.706    0.810    0.098    0.125    0.313    0.128
# 14   ...    0.865    0.181    0.003    0.668    0.968    0.120    0.701
# 219  ...    0.324    0.560    0.104    0.154    0.643    0.199    0.647
# 208  ...    0.168    0.864    0.181    0.451    0.667    0.879    0.854
#
#      var_198  var_199  var_200
# 45     0.310    0.284    0.195
# 158    0.978    0.234    0.984
# 14     0.281    0.254    0.135
# 219    0.399    0.539    0.862
# 208    0.531    0.382    0.123
#
# [5 rows x 201 columns]

# %%
df.describe()
# Out:
#            target       var_1       var_2       var_3       var_4       var_5  \
# count  250.000000  250.000000  250.000000  250.000000  250.000000  250.000000
# mean     0.524000    0.515564    0.499984    0.491172    0.533664    0.493556
# std      0.500426    0.295878    0.303769    0.288538    0.284235    0.290833
# min      0.000000    0.004000    0.005000    0.007000    0.002000    0.008000
# 25%      0.000000    0.244000    0.234250    0.260000    0.291750    0.225750
# 50%      1.000000    0.544000    0.497500    0.465500    0.516500    0.487500
# 75%      1.000000    0.755500    0.761250    0.725000    0.785000    0.747750
# max      1.000000    0.989000    0.999000    0.996000    0.997000    0.992000
#
#             var_6       var_7       var_8       var_9  ...     var_191  \
# count  250.000000  250.000000  250.000000  250.000000  ...  250.000000
# mean     0.493308    0.503380    0.490580    0.508116  ...    0.494188
# std      0.294168    0.279257    0.290459    0.295278  ...    0.293931
# min      0.003000    0.003000    0.006000    0.001000  ...    0.007000
# 25%      0.224500    0.282250    0.251750    0.232000  ...    0.224250
# 50%      0.511500    0.524000    0.479500    0.509000  ...    0.481500
# 75%      0.746250    0.718500    0.736500    0.762000  ...    0.760000
# max      0.991000    0.988000    0.999000    0.998000  ...    0.998000
#
#           var_192     var_193     var_194     var_195     var_196     var_197  \
# count  250.000000  250.000000  250.000000  250.000000  250.000000  250.000000
# mean     0.483484    0.489176    0.476996    0.506612    0.487852    0.485272
# std      0.282872    0.285203    0.289716    0.292900    0.280595    0.286139
# min      0.003000    0.003000    0.005000    0.003000    0.003000    0.013000
# 25%      0.253250    0.219250    0.213000    0.249000    0.260750    0.238000
# 50%      0.460500    0.493000    0.482500    0.511500    0.474500    0.479500
# 75%      0.717250    0.744750    0.725750    0.759750    0.727750    0.747750
# max      1.000000    0.980000    0.989000    0.998000    0.988000    1.000000
#
#           var_198     var_199     var_200
# count  250.000000  250.000000  250.000000
# mean     0.499436    0.484928    0.494028
# std      0.300880    0.281306    0.300464
# min      0.002000    0.003000    0.003000
# 25%      0.240250    0.245500    0.229000
# 50%      0.484000    0.507500    0.491000
# 75%      0.777250    0.705000    0.760250
# max      1.000000    0.999000    0.998000
#
# [8 rows x 201 columns]

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
from sklearn.model_selection import train_test_split

#Trees don't theoretically require dummies, but sklearns implemention does.
df2 = pd.get_dummies(df, drop_first=True)
y = np.array(df2["target"]).reshape(-1,1)
X = np.array(df2.drop(columns={"target"}))

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

clf = DecisionTreeClassifier(random_state=0)
clf = clf.fit(X_train, y_train)
print(clf.get_depth())
print("Training Accuracy:", clf.score(X_train, y_train))
print("Testing Accuracy:", clf.score(X_test, y_test))
plt.figure(figsize=(25,20))
plot_tree(clf, feature_names=df.columns[:-1], class_names=["False","True"])
# Out:
# 9
# Training Accuracy: 1.0
# Testing Accuracy: 0.5238095238095238
# [Text(481.51278409090907, 1032.8400000000001, 'var_177 <= 0.117\ngini = 0.499\nsamples = 187\nvalue = [89, 98]\nclass = True'),
#  Text(182.30113636363635, 924.1200000000001, 'var_141 <= 0.153\ngini = 0.231\nsamples = 30\nvalue = [4, 26]\nclass = True'),
#  Text(118.89204545454545, 815.4000000000001, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = False'),
#  Text(245.71022727272725, 815.4000000000001, 'var_152 <= 0.938\ngini = 0.071\nsamples = 27\nvalue = [1, 26]\nclass = True'),
#  Text(182.30113636363635, 706.6800000000001, 'gini = 0.0\nsamples = 26\nvalue = [0, 26]\nclass = True'),
#  Text(309.1193181818182, 706.6800000000001, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = False'),
#  Text(780.7244318181818, 924.1200000000001, 'var_199 <= 0.854\ngini = 0.497\nsamples = 157\nvalue = [85, 72]\nclass = False'),
#  Text(499.3465909090909, 815.4000000000001, 'var_152 <= 0.847\ngini = 0.477\nsamples = 130\nvalue = [79, 51]\nclass = False'),
#  Text(435.9375, 706.6800000000001, 'var_133 <= 0.342\ngini = 0.496\nsamples = 112\nvalue = [61, 51]\nclass = False'),
#  Text(126.81818181818181, 597.96, 'var_148 <= 0.099\ngini = 0.327\nsamples = 34\nvalue = [27, 7]\nclass = False'),
#  Text(63.40909090909091, 489.24, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = True'),
#  Text(190.22727272727272, 489.24, 'var_94 <= 0.146\ngini = 0.225\nsamples = 31\nvalue = [27, 4]\nclass = False'),
#  Text(126.81818181818181, 380.5200000000001, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = True'),
#  Text(253.63636363636363, 380.5200000000001, 'var_157 <= 0.979\ngini = 0.128\nsamples = 29\nvalue = [27, 2]\nclass = False'),
#  Text(190.22727272727272, 271.80000000000007, 'gini = 0.0\nsamples = 27\nvalue = [27, 0]\nclass = False'),
#  Text(317.0454545454545, 271.80000000000007, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = True'),
#  Text(745.0568181818181, 597.96, 'var_139 <= 0.32\ngini = 0.492\nsamples = 78\nvalue = [34, 44]\nclass = True'),
#  Text(570.6818181818181, 489.24, 'var_18 <= 0.209\ngini = 0.227\nsamples = 23\nvalue = [3, 20]\nclass = True'),
#  Text(507.27272727272725, 380.5200000000001, 'var_117 <= 0.277\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = False'),
#  Text(443.8636363636364, 271.80000000000007, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = True'),
#  Text(570.6818181818181, 271.80000000000007, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = False'),
#  Text(634.090909090909, 380.5200000000001, 'gini = 0.0\nsamples = 19\nvalue = [0, 19]\nclass = True'),
#  Text(919.4318181818181, 489.24, 'var_196 <= 0.242\ngini = 0.492\nsamples = 55\nvalue = [31, 24]\nclass = False'),
#  Text(760.9090909090909, 380.5200000000001, 'var_58 <= 0.097\ngini = 0.231\nsamples = 15\nvalue = [2, 13]\nclass = True'),
#  Text(697.5, 271.80000000000007, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = False'),
#  Text(824.3181818181818, 271.80000000000007, 'gini = 0.0\nsamples = 13\nvalue = [0, 13]\nclass = True'),
#  Text(1077.9545454545455, 380.5200000000001, 'var_33 <= 0.306\ngini = 0.399\nsamples = 40\nvalue = [29, 11]\nclass = False'),
#  Text(951.1363636363636, 271.80000000000007, 'var_84 <= 0.641\ngini = 0.444\nsamples = 12\nvalue = [4, 8]\nclass = True'),
#  Text(887.7272727272727, 163.08000000000004, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]\nclass = True'),
#  Text(1014.5454545454545, 163.08000000000004, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = False'),
#  Text(1204.7727272727273, 271.80000000000007, 'var_103 <= 0.101\ngini = 0.191\nsamples = 28\nvalue = [25, 3]\nclass = False'),
#  Text(1141.3636363636363, 163.08000000000004, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = True'),
#  Text(1268.181818181818, 163.08000000000004, 'var_166 <= 0.068\ngini = 0.074\nsamples = 26\nvalue = [25, 1]\nclass = False'),
#  Text(1204.7727272727273, 54.36000000000013, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = True'),
#  Text(1331.590909090909, 54.36000000000013, 'gini = 0.0\nsamples = 25\nvalue = [25, 0]\nclass = False'),
#  Text(562.7556818181818, 706.6800000000001, 'gini = 0.0\nsamples = 18\nvalue = [18, 0]\nclass = False'),
#  Text(1062.1022727272727, 815.4000000000001, 'var_91 <= 0.723\ngini = 0.346\nsamples = 27\nvalue = [6, 21]\nclass = True'),
#  Text(935.2840909090909, 706.6800000000001, 'var_42 <= 0.091\ngini = 0.095\nsamples = 20\nvalue = [1, 19]\nclass = True'),
#  Text(871.875, 597.96, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = False'),
#  Text(998.6931818181818, 597.96, 'gini = 0.0\nsamples = 19\nvalue = [0, 19]\nclass = True'),
#  Text(1188.9204545454545, 706.6800000000001, 'var_136 <= 0.809\ngini = 0.408\nsamples = 7\nvalue = [5, 2]\nclass = False'),
#  Text(1125.5113636363635, 597.96, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = False'),
#  Text(1252.3295454545455, 597.96, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = True')]

# %%
importances = clf.feature_importances_
feat_imp = pd.Series(importances, index=df2.drop(columns={"target"}).columns)
feat_imp.sort_values(ascending=False)[0:5]
# Out:
# var_178    0.089923
# var_153    0.089587
# var_197    0.081878
# var_200    0.071222
# var_140    0.065253
# dtype: float64

# %%
#Tree with entropy
clf = DecisionTreeClassifier(criterion="entropy")
clf = clf.fit(X_train, y_train)

print(clf.get_depth())
print("Training Accuracy:", clf.score(X_train, y_train))
print("Testing Accuracy:", clf.score(X_test, y_test))
plt.figure(figsize=(25,20))
plot_tree(clf, feature_names=df.columns[:-1], class_names=["False","True"])
# Out:
# 12
# Training Accuracy: 1.0
# Testing Accuracy: 0.49206349206349204
# [Text(784.6875, 1045.3846153846155, 'var_177 <= 0.117\nentropy = 0.998\nsamples = 187\nvalue = [89, 98]\nclass = True'),
#  Text(523.125, 961.7538461538462, 'var_141 <= 0.153\nentropy = 0.567\nsamples = 30\nvalue = [4, 26]\nclass = True'),
#  Text(435.9375, 878.123076923077, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = False'),
#  Text(610.3125, 878.123076923077, 'var_23 <= 0.006\nentropy = 0.229\nsamples = 27\nvalue = [1, 26]\nclass = True'),
#  Text(523.125, 794.4923076923078, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = False'),
#  Text(697.5, 794.4923076923078, 'entropy = 0.0\nsamples = 26\nvalue = [0, 26]\nclass = True'),
#  Text(1046.25, 961.7538461538462, 'var_42 <= 0.912\nentropy = 0.995\nsamples = 157\nvalue = [85, 72]\nclass = False'),
#  Text(959.0625, 878.123076923077, 'var_49 <= 0.931\nentropy = 1.0\nsamples = 145\nvalue = [73, 72]\nclass = False'),
#  Text(871.875, 794.4923076923078, 'var_6 <= 0.927\nentropy = 0.997\nsamples = 135\nvalue = [63, 72]\nclass = True'),
#  Text(784.6875, 710.8615384615384, 'var_122 <= 0.958\nentropy = 0.985\nsamples = 126\nvalue = [54, 72]\nclass = True'),
#  Text(697.5, 627.2307692307693, 'var_28 <= 0.693\nentropy = 0.965\nsamples = 118\nvalue = [46, 72]\nclass = True'),
#  Text(348.75, 543.6, 'var_126 <= 0.524\nentropy = 0.863\nsamples = 84\nvalue = [24, 60]\nclass = True'),
#  Text(174.375, 459.96923076923076, 'var_152 <= 0.039\nentropy = 0.477\nsamples = 39\nvalue = [4, 35]\nclass = True'),
#  Text(87.1875, 376.3384615384616, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = False'),
#  Text(261.5625, 376.3384615384616, 'var_16 <= 0.866\nentropy = 0.303\nsamples = 37\nvalue = [2, 35]\nclass = True'),
#  Text(174.375, 292.70769230769235, 'entropy = 0.0\nsamples = 35\nvalue = [0, 35]\nclass = True'),
#  Text(348.75, 292.70769230769235, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = False'),
#  Text(523.125, 459.96923076923076, 'var_132 <= 0.204\nentropy = 0.991\nsamples = 45\nvalue = [20, 25]\nclass = True'),
#  Text(435.9375, 376.3384615384616, 'entropy = 0.0\nsamples = 10\nvalue = [0, 10]\nclass = True'),
#  Text(610.3125, 376.3384615384616, 'var_64 <= 0.792\nentropy = 0.985\nsamples = 35\nvalue = [20, 15]\nclass = False'),
#  Text(523.125, 292.70769230769235, 'var_178 <= 0.171\nentropy = 0.983\nsamples = 26\nvalue = [11, 15]\nclass = True'),
#  Text(435.9375, 209.0769230769231, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = False'),
#  Text(610.3125, 209.0769230769231, 'var_18 <= 0.353\nentropy = 0.863\nsamples = 21\nvalue = [6, 15]\nclass = True'),
#  Text(523.125, 125.44615384615383, 'var_197 <= 0.766\nentropy = 0.811\nsamples = 8\nvalue = [6, 2]\nclass = False'),
#  Text(435.9375, 41.81538461538457, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = False'),
#  Text(610.3125, 41.81538461538457, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = True'),
#  Text(697.5, 125.44615384615383, 'entropy = 0.0\nsamples = 13\nvalue = [0, 13]\nclass = True'),
#  Text(697.5, 292.70769230769235, 'entropy = 0.0\nsamples = 9\nvalue = [9, 0]\nclass = False'),
#  Text(1046.25, 543.6, 'var_35 <= 0.214\nentropy = 0.937\nsamples = 34\nvalue = [22, 12]\nclass = False'),
#  Text(871.875, 459.96923076923076, 'var_153 <= 0.787\nentropy = 0.779\nsamples = 13\nvalue = [3, 10]\nclass = True'),
#  Text(784.6875, 376.3384615384616, 'entropy = 0.0\nsamples = 10\nvalue = [0, 10]\nclass = True'),
#  Text(959.0625, 376.3384615384616, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = False'),
#  Text(1220.625, 459.96923076923076, 'var_31 <= 0.099\nentropy = 0.454\nsamples = 21\nvalue = [19, 2]\nclass = False'),
#  Text(1133.4375, 376.3384615384616, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = True'),
#  Text(1307.8125, 376.3384615384616, 'entropy = 0.0\nsamples = 19\nvalue = [19, 0]\nclass = False'),
#  Text(871.875, 627.2307692307693, 'entropy = 0.0\nsamples = 8\nvalue = [8, 0]\nclass = False'),
#  Text(959.0625, 710.8615384615384, 'entropy = 0.0\nsamples = 9\nvalue = [9, 0]\nclass = False'),
#  Text(1046.25, 794.4923076923078, 'entropy = 0.0\nsamples = 10\nvalue = [10, 0]\nclass = False'),
#  Text(1133.4375, 878.123076923077, 'entropy = 0.0\nsamples = 12\nvalue = [12, 0]\nclass = False')]

# %%
#limit depth
clf = DecisionTreeClassifier(max_depth=3)
clf = clf.fit(X_train, y_train)

print(clf.get_depth())
print("Training Accuracy:", clf.score(X_train, y_train))
print("Testing Accuracy:", clf.score(X_test, y_test))
plt.figure(figsize=(25,20))
plot_tree(clf, feature_names=df.columns[:-1], class_names=["False","True"])
# Out:
# 3
# Training Accuracy: 0.7112299465240641
# Testing Accuracy: 0.5238095238095238
# [Text(590.1923076923077, 951.3000000000001, 'var_177 <= 0.117\ngini = 0.499\nsamples = 187\nvalue = [89, 98]\nclass = True'),
#  Text(214.6153846153846, 679.5, 'var_141 <= 0.153\ngini = 0.231\nsamples = 30\nvalue = [4, 26]\nclass = True'),
#  Text(107.3076923076923, 407.70000000000005, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = False'),
#  Text(321.9230769230769, 407.70000000000005, 'var_120 <= 0.964\ngini = 0.071\nsamples = 27\nvalue = [1, 26]\nclass = True'),
#  Text(214.6153846153846, 135.89999999999998, 'gini = 0.0\nsamples = 26\nvalue = [0, 26]\nclass = True'),
#  Text(429.2307692307692, 135.89999999999998, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = False'),
#  Text(965.7692307692307, 679.5, 'var_199 <= 0.854\ngini = 0.497\nsamples = 157\nvalue = [85, 72]\nclass = False'),
#  Text(751.1538461538462, 407.70000000000005, 'var_152 <= 0.847\ngini = 0.477\nsamples = 130\nvalue = [79, 51]\nclass = False'),
#  Text(643.8461538461538, 135.89999999999998, 'gini = 0.496\nsamples = 112\nvalue = [61, 51]\nclass = False'),
#  Text(858.4615384615385, 135.89999999999998, 'gini = 0.0\nsamples = 18\nvalue = [18, 0]\nclass = False'),
#  Text(1180.3846153846155, 407.70000000000005, 'var_91 <= 0.723\ngini = 0.346\nsamples = 27\nvalue = [6, 21]\nclass = True'),
#  Text(1073.076923076923, 135.89999999999998, 'gini = 0.095\nsamples = 20\nvalue = [1, 19]\nclass = True'),
#  Text(1287.6923076923076, 135.89999999999998, 'gini = 0.408\nsamples = 7\nvalue = [5, 2]\nclass = False')]

# %%
#limit depth
clf = DecisionTreeClassifier()

path = clf.cost_complexity_pruning_path(X_train, y_train)
ccp_alphas, impurities = path.ccp_alphas, path.impurities

fig, ax = plt.subplots()
ax.plot(ccp_alphas[:-1], impurities[:-1], marker="o", drawstyle="steps-post")
ax.set_xlabel("effective alpha")
ax.set_ylabel("total impurity of leaves")
ax.set_title("Total Impurity vs effective alpha for training set")
# Out:
# Text(0.5, 1.0, 'Total Impurity vs effective alpha for training set')

# %%
clfs = []
for ccp_alpha in ccp_alphas:
    clf = DecisionTreeClassifier(random_state=0, ccp_alpha=ccp_alpha)
    clf.fit(X_train, y_train)
    clfs.append(clf)

clfs = clfs[:-1]
ccp_alphas = ccp_alphas[:-1]

node_counts = [clf.tree_.node_count for clf in clfs]
depth = [clf.tree_.max_depth for clf in clfs]
fig, ax = plt.subplots(2, 1)
ax[0].plot(ccp_alphas, node_counts, marker="o", drawstyle="steps-post")
ax[0].set_xlabel("alpha")
ax[0].set_ylabel("number of nodes")
ax[0].set_title("Number of nodes vs alpha")
ax[1].plot(ccp_alphas, depth, marker="o", drawstyle="steps-post")
ax[1].set_xlabel("alpha")
ax[1].set_ylabel("depth of tree")
ax[1].set_title("Depth vs alpha")
fig.tight_layout()

# %%
train_scores = [clf.score(X_train, y_train) for clf in clfs]
test_scores = [clf.score(X_test, y_test) for clf in clfs]

fig, ax = plt.subplots()
ax.set_xlabel("alpha")
ax.set_ylabel("accuracy")
ax.set_title("Accuracy vs alpha for training and testing sets")
ax.plot(ccp_alphas, train_scores, marker="o", label="train", drawstyle="steps-post")
ax.plot(ccp_alphas, test_scores, marker="o", label="test", drawstyle="steps-post")
ax.legend()
plt.show()

# %%
print(best.score(X_test, y_test))
print(best)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-3d9c797a8472> in <module>
# ----> 1 print(best.score(X_test, y_test))
#       2 print(best)
#
# NameError: name 'best' is not defined

# %% [markdown]
# ### Testing
#
# Please leave the stuff below as-is in your file.
#
# This will take your best model and score it with the test data. If you want to test to make sure that yours works, make a copy of the data file and rename it testing.csv, then make sure this runs ok. I will do the same, but the contents of my test file will be different.

# %%
#Load Test Data
test_df = pd.read_csv("testing.csv")
test_df = test_df.drop(columns={"id"})
#Create tests and score
test_y = np.array(test_df["target"]).reshape(-1,1)
test_X = np.array(test_df.drop(columns={"target"}))

preds = best.predict(test_X)

roc_score = roc_auc_score(test_y, preds)
acc_score = accuracy_score(test_y, preds)

print(roc_score)
print(acc_score)
print(name, np.mean([roc_score, acc_score]))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-18-83fa37d128c5> in <module>
#       1 #Load Test Data
# ----> 2 test_df = pd.read_csv("testing.csv")
#       3 test_df = test_df.drop(columns={"id"})
#       4 #Create tests and score
#       5 test_y = np.array(test_df["target"]).reshape(-1,1)
#
# c:\Users\Nneka\anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# c:\Users\Nneka\anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# c:\Users\Nneka\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     944             self.options["has_index_names"] = kwds["has_index_names"]
#     945
# --> 946         self._make_engine(self.engine)
#     947
#     948     def close(self):
#
# c:\Users\Nneka\anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1176     def _make_engine(self, engine="c"):
#    1177         if engine == "c":
# -> 1178             self._engine = CParserWrapper(self.f, **self.options)
#    1179         else:
#    1180             if engine == "python":
#
# c:\Users\Nneka\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    2006         kwds["usecols"] = self.usecols
#    2007
# -> 2008         self._reader = parsers.TextReader(src, **kwds)
#    2009         self.unnamed_cols = self._reader.unnamed_cols
#    2010
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'testing.csv'

# %% [markdown]
# ### What Accuracy Changes Were Used
#
# Please list here what you did to try to increase accuracy and/or limit overfitting:
# <ul>
# <li>
# <li>
# </ul>
